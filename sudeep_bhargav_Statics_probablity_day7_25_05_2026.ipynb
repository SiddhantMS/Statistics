# %% [markdown]
# <a href="https://colab.research.google.com/github/SiddhantMS/Statistics/blob/main/sudeep_bhargav_Statics_probablity_day7_25_05_2026.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import scipy
from scipy import stats
from scipy.stats import binom,poisson,norm,t

# %%
norm.cdf(43,45,2.8)
# Out:
# np.float64(0.2375252620269765)

# %%
norm.pdf(43,45,2.8)
# Out:
# np.float64(0.11039836100680946)

# %%
poisson.cdf(43,45,2.8)
# Out:
# np.float64(0.2555450779281301)

# %%
#poisson.pdf(43,45)

# %%
poisson.sf(43,45)
# Out:
# np.float64(0.5791867033138671)

# %% [markdown]
# student t distribution

# %%
z = (14-15.3)/1.8

# %%
t.cdf(z,14)
# Out:
# np.float64(0.2410240907076217)

# %%
norm.cdf(z)  # answe will be not exact but equal to or almost match
# but in std. t dis we take sample devation not like normal should have greter han 30
# Out:
# np.float64(0.23507893142883468)

# %%
z = (30-15.3/1.8)

# %%
t.cdf(z,14)
# Out:
# np.float64(0.9999999999979872)

# %%
norm.cdf(z)
# Out:
# np.float64(1.0)

# %% [markdown]
# Exponential distrubution

# %%
1/0.3
# Out:
# 3.3333333333333335

# %%
 #jonson sir comes 30 times in a 45 days and lecture is 8 hr

# %%
(45*8)/30
# Out:
# 12.0

# %%
from scipy.stats import expon

# %%
expon.cdf(8,scale=12)
# Out:
# np.float64(0.486582880967408)

# %%
#70% in batch of 15 student how many

# %% [markdown]
# EDA - EXPLORATORY DATA ANALYSIS

# %% [markdown]
# QUESTION IS HOW WE WILL FILL NULL VALUES IN DATA WHAT SHOULD BE APPROCH

# %%
import os
os.chdir(r"/content/drive/MyDrive/stats")

# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_excel('data1.xlsx')

# %%
df.head()
# Out:
#   Category
# 0        C
# 1        D
# 2        C
# 3        A
# 4        B

# %%
df.Category.isnull().sum()
# Out:
# np.int64(80)

# %%
np.where(df.Category.isnull())
# Out:
# (array([  9,  11,  15,  32,  35,  38,  47,  48,  58,  59,  62,  64,  80,
#          81,  82,  84,  95,  98, 122, 123, 140, 156, 161, 163, 164, 165,
#         166, 167, 170, 174, 176, 177, 188, 192, 193, 212, 217, 223, 227,
#         231, 237, 238, 246, 248, 250, 254, 257, 260, 267, 268, 269, 278,
#         281, 287, 303, 328, 329, 333, 342, 345, 349, 357, 382, 384, 387,
#         404, 406, 441, 445, 447, 451, 456, 459, 464, 471, 476, 477, 490,
#         492, 494]),)

# %%
80/df.shape[0]
# Out:
# 0.16

# %%
from collections import Counter

# %%
Counter(df.Category).most_common()
# Out:
# [('B', 113), ('A', 112), ('C', 101), ('D', 94), (nan, 80)]

# %%
df.Category.fillna('B')  # this has not change the original df
# if we want to chant to original then
# df.Category = df.Category.fillna('B')
# df.Category.fillna('B',inplace = True)
# Out:
# 0      C
# 1      D
# 2      C
# 3      A
# 4      B
#       ..
# 495    C
# 496    C
# 497    D
# 498    B
# 499    A
# Name: Category, Length: 500, dtype: object

# %%
df.Category = df.Category.fillna('B')

# %%
df.Category.isnull().sum()
# Out:
# np.int64(0)

# %%
df = pd.read_excel('data1.xlsx')

# %%
df.Category.isnull().sum()
# Out:
# np.int64(80)

# %%
props = pd.DataFrame(df.Category.value_counts())

# %%
props
# Out:
#           count
# Category
# B           113
# A           112
# C           101
# D            94

# %%
props['proportion'] = props['count']/sum(props['count'])

# %%
props
# Out:
#           count  proportion
# Category
# B           113    0.269048
# A           112    0.266667
# C           101    0.240476
# D            94    0.223810

# %%
random_values = np.random.choice(['A','B','C','D'],size=80,p=props.proportion)
#here we have taken 80 random values of a b c d  in the proportion we hant

# %%
random_values
# Out:
# array(['A', 'A', 'A', 'B', 'D', 'D', 'B', 'B', 'C', 'C', 'A', 'A', 'B',
#        'B', 'A', 'D', 'C', 'B', 'A', 'D', 'B', 'A', 'D', 'D', 'B', 'C',
#        'D', 'B', 'D', 'B', 'A', 'D', 'B', 'A', 'B', 'C', 'D', 'A', 'B',
#        'C', 'A', 'C', 'D', 'C', 'A', 'C', 'D', 'B', 'D', 'B', 'C', 'D',
#        'A', 'A', 'D', 'A', 'D', 'C', 'B', 'D', 'A', 'C', 'A', 'D', 'C',
#        'B', 'A', 'A', 'B', 'D', 'D', 'C', 'B', 'C', 'D', 'A', 'D', 'C',
#        'A', 'C'], dtype='<U1')

# %%
ind = np.where(df.Category.isnull())

# %%
ind
# Out:
# (array([  9,  11,  15,  32,  35,  38,  47,  48,  58,  59,  62,  64,  80,
#          81,  82,  84,  95,  98, 122, 123, 140, 156, 161, 163, 164, 165,
#         166, 167, 170, 174, 176, 177, 188, 192, 193, 212, 217, 223, 227,
#         231, 237, 238, 246, 248, 250, 254, 257, 260, 267, 268, 269, 278,
#         281, 287, 303, 328, 329, 333, 342, 345, 349, 357, 382, 384, 387,
#         404, 406, 441, 445, 447, 451, 456, 459, 464, 471, 476, 477, 490,
#         492, 494]),)

# %%
df.loc[ind[0],'Category'] = random_values

# %%
df.Category.isnull().sum()
# Out:
# np.int64(0)

# %%
A_props = pd.DataFrame(df.Category.value_counts())

# %%
A_props
# Out:
#           count
# Category
# A           134
# B           132
# C           118
# D           116

# %%
A_props['proportion'] = A_props['count']/sum(A_props['count'])

# %%
A_props
# Out:
#           count  proportion
# Category
# A           134       0.268
# B           132       0.264
# C           118       0.236
# D           116       0.232

# %%
df= pd.read_excel('data2.xlsx')

# %%
df
# Out:
#     Category  Continuous_Value
# 0          C      -4008.098297
# 1          D      -3887.888132
# 2        NaN      -3712.188312
# 3          C      -3416.823821
# 4          D      -5845.073897
# ..       ...               ...
# 995        C       4254.526508
# 996        D       4056.149295
# 997        A               NaN
# 998        A       4734.230414
# 999        B               NaN
#
# [1000 rows x 2 columns]

# %%
df.Continuous_Value.isnull().sum()
# Out:
# np.int64(120)

# %%
df.Category.isnull().sum()
# Out:
# np.int64(150)

# %%
df1 = df.Continuous_Value.fillna(df.Continuous_Value.median())

# %%
df1.head()
# Out:
# 0   -4008.098297
# 1   -3887.888132
# 2   -3712.188312
# 3   -3416.823821
# 4   -5845.073897
# Name: Continuous_Value, dtype: float64

# %%
df1.info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 1000 entries, 0 to 999
# Series name: Continuous_Value
# Non-Null Count  Dtype
# --------------  -----
# 1000 non-null   float64
# dtypes: float64(1)
# memory usage: 7.9 KB

# %% [markdown]
# graph

# %%
import seaborn as sns
import matplotlib
import matplotlib.pyplot as plt
import pylab
from pylab import legend
from pylab import plot,show,title
from pylab import xlabel,ylabel

# %%
# the different bars in barchat doesnot touch each other and will be of equal thikness.

# %%
states = ['KA','MH','AP','MP','UP']
counts = [40,35,50,20,15]

# %%
plt.bar(states,counts)
# Out:
# <BarContainer object of 5 artists>

# %%
sns.barplot(x=states,y=counts)
# Out:
# <Axes: >

# %%
sns.barplot(x=states,y=counts)
plt.title('This is my first graph')
plt.xlabel('Name of the states')
plt.ylabel('counts')
plt.show()

# %%
df = pd.read_excel('CDAC_DataBook.xlsx', sheet_name='ERPData')

# %%
df.head()
# Out:
#   MaterialID Location  Quantity
# 0    TMI-43T    MWH-4        34
# 1    AXCP-78    MWH-1        67
# 2    LXCV-21    MWH-2        27
# 3    AXCP-78    MWH-5        65
# 4    AXCP-78    MWH-4        36

# %%
df1 = df.MaterialID.value_counts()

# %%
plt.bar(df1.index,df1)
# Out:
# <BarContainer object of 6 artists>

# %%
df2 = df.Location.value_counts()

# %%
plt.bar(df2.index,df2)
# Out:
# <BarContainer object of 5 artists>

# %%
df1 = df.sum(np.unique('MaterialID'))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_1019/3906337530.py in <cell line: 0>()
# ----> 1 df1 = df.sum(np.unique('MaterialID'))
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/frame.py in sum(self, axis, skipna, numeric_only, min_count, **kwargs)
#   11668         **kwargs,
#   11669     ):
# > 11670         result = super().sum(axis, skipna, numeric_only, min_count, **kwargs)
#   11671         return result.__finalize__(self, method="sum")
#   11672
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/generic.py in sum(self, axis, skipna, numeric_only, min_count, **kwargs)
#   12504         **kwargs,
#   12505     ):
# > 12506         return self._min_count_stat_function(
#   12507             "sum", nanops.nansum, axis, skipna, numeric_only, min_count, **kwargs
#   12508         )
#
# ...

# %%
df1 = df.groupby(df.MaterialID)

# %%
df1.get_group()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_1019/746406842.py in <cell line: 0>()
# ----> 1 df1.get_group()
#
# TypeError: BaseGroupBy.get_group() missing 1 required positional argument: 'name'

# %%
df2 = df1.Quantity.agg('sum')

# %%
df2
# Out:
# MaterialID
# AXCP-78    898
# DDBN-89    383
# GCVB-79    182
# LXCV-21    243
# SDRT-67    294
# TMI-43T    885
# Name: Quantity, dtype: int64

# %%
plt.bar(df2.index,df2)
# Out:
# <BarContainer object of 6 artists>

# %%
df1 = pd.crosstab(df.Location,df.MaterialID)

# %%
df1
# Out:
# MaterialID  AXCP-78  DDBN-89  GCVB-79  LXCV-21  SDRT-67  TMI-43T
# Location
# MWH-1             5        3        0        0        2        1
# MWH-2             1        1        4        1        1        1
# MWH-3             1        1        0        1        0        1
# MWH-4             1        2        0        0        1       11
# MWH-5             3        1        1        3        2        1

# %%
df1.plot(kind='bar')
# Out:
# <Axes: xlabel='Location'>

# %%
df = pd.read_excel('CDAC_DataBook.xlsx', sheet_name='nominal')

# %%
df.head()
# Out:
#    ses  write  math  prog
# 0    1     35    41     1
# 1    2     33    41     2
# 2    3     39    44     3
# 3    1     37    42     1
# 4    2     31    40     2

# %%
df1= pd.crosstab(df.ses,df.prog)

# %%
df1.plot(kind = 'bar')
# Out:
# <Axes: xlabel='ses'>

# %%
#see influense the graph of program because as we can see from ses1 to ses3 the prog1 is decreasing and prog3 is increasing
# we can also say that the ses and prog are inversely proportional to each other

# %%
#when we want to make effect of a categorical data on another categorical data willl make a group bar chart

# %%
df = pd.read_excel('CDAC_DataBook.xlsx', sheet_name='ERPData')

# %%
plt.boxplot(df.Quantity)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7c4eabd8b6e0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x7c4eabd8bbf0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x7c4eabd8b260>],
#  'medians': [<matplotlib.lines.Line2D at 0x7c4eabd88d40>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7c4eabd88b60>],
#  'means': []}

# %%
male_sal = [4,5,6,3,7,6,8]
female_sal = [11,15,12,19,15]

# %%
plt.boxplot([male_sal,female_sal])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7c4eabf76930>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x7c4eac882870>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x7c4eabf76de0>,
# ...
#  'medians': [<matplotlib.lines.Line2D at 0x7c4eac880b00>,
# ...
#  'fliers': [<matplotlib.lines.Line2D at 0x7c4eac880a70>,
# ...
#  'means': []}
