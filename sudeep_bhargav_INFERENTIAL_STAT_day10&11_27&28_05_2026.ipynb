# %% [markdown]
# <a href="https://colab.research.google.com/github/SiddhantMS/Statistics/blob/main/sudeep_bhargav_INFERENTIAL_STAT_day10%2611_27%2628_05_2026.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import warnings
warnings.filterwarnings("ignore")
pd.set_option('display.max_columns', None)
from numpy import random
from collections import Counter
from numpy.linalg import inv
from numpy.linalg import eig
import matplotlib
from matplotlib import pyplot as plt
import seaborn as sns
import pylab
from pylab import legend
from pylab import plot, show, title, xlabel, ylabel
import scipy
from scipy import stats
from scipy.stats import binom,poisson,norm,t,expon
from sklearn.model_selection import train_test_split
import statsmodels
from statsmodels import stats
from statsmodels.stats import weightstats as ssw

# %%
n = 300
Xbar =1800
stdev = 70
cl = 0.95

# %%
norm.ppf((1-cl)/2)
# Out:
# np.float64(-1.959963984540054)

# %%
z = np.abs(norm.ppf((1-cl)/2))

# %%
z
# Out:
# np.float64(1.959963984540054)

# %%
# for t distribution
t1 = np.abs(t.ppf((1-cl)/2,n-1))

# %%
t1
# Out:
# np.float64(1.9679296690653618)

# %%
low_est = Xbar - t1*stdev/n**0.5
upper_est = Xbar + t1*stdev/n**0.5

# %%
size = upper_est - low_est

# %%
size
# Out:
# np.float64(15.906586138536113)

# %%
#stats.t.interval(confidence level,degreeoflevel(ddof),sample mean ,std err of mean)

# %%
stats.t.interval(cl,n-1,Xbar,stdev/n**0.5)
# Out:
# (np.float64(1792.046706930732), np.float64(1807.953293069268))

# %% [markdown]
# day 11

# %%
import os
os.chdir(r"/content/drive/MyDrive/stats")
import numpy as np
import pandas as pd

# %%
df = pd.read_excel('CDAC_DataBook.xlsx',sheet_name='faithful')

# %%
erupt = df.eruptions

# %%
xbar = np.mean(erupt)
n = len(erupt)
sd = np.std(erupt,ddof=1)

# %%
# 1 sample z test
# 1 sample t test
#1-sample z test/ 1 sample t test

#Used to check whether the difference betweent the sample mean and claim value can be ignored or not.

#Used to check whether the difference betweent the sample mean and claim value is statistically significant or not

# %%
# step-1 - make a null hypotersis

# %%
import statsmodels
from statsmodels import stats
from statsmodels.stats import weightstats as ssw

# %%
ssw.ztest(erupt,value = 3.6, alternative='smaller')
# Out:
# (np.float64(-1.621495827018525), np.float64(0.052455672107759366))

# %%
z = (xbar - 3.7)/(sd/n**0.5)

# %%
z
# Out:
# np.float64(-3.066461475706521)

# %%
norm.ppf(z)
# Out:
# np.float64(nan)

# %%
ssw.ztest(erupt,value = 3.53, alternative='smaller')
# Out:
# (np.float64(-0.6100198729369251), np.float64(0.27092432161445423))

# %%
z =(xbar - 3.53)/(sd/n**0.5)

# %%
z
# Out:
# np.float64(-0.6100198729369253)

# %%
norm.cdf(z)
# Out:
# np.float64(0.2709243216144542)

# %%
# u will not exceed 3.37 u<= 3.37

# %%
ssw.ztest(erupt,value = 3.37, alternative='smaller')
# Out:
# (np.float64(1.7019251649638607), np.float64(0.9556153011567042))

# %%
z =(xbar - 3.37)/(sd/n**0.5)
z
# Out:
# np.float64(1.7019251649638614)

# %%
norm.ppf(0.9556153011567042)
# Out:
# np.float64(1.7019251649638605)

# %%
1-norm.cdf(1.7)
# Out:
# np.float64(0.044565462758543006)

# %%
xbar=np.mean(df.waiting)
enpt =df.waiting
n = len(enpt)
sd = np.std(enpt,ddof=1)

# %%
z =(xbar - 75)/(sd/n**0.5)
z
# Out:
# np.float64(-4.977386527579323)

# %%
norm.ppf(0.05)
# Out:
# np.float64(-1.6448536269514729)

# %%
ssw.ztest(df.waiting,value = 75, alternative='smaller')
# Out:
# (np.float64(-4.9773865275793225), np.float64(3.222427049500608e-07))

# %%
norm.cdf(z)
# Out:
# np.float64(3.222427049500585e-07)

# %%
xbar + (1.645*sd)/(n**0.05)
# Out:
# np.float64(87.79430112304033)

# %%
xbar
# Out:
# np.float64(70.8970588235294)

# %%
sd
# Out:
# 13.594973789999393

# %%
n
# Out:
# 272

# %%
xbar + 1.645*sd/n**0.05
# Out:
# np.float64(87.79430112304033)

# %%
'''
clame-Travel in Blore is atleast 15 min more than Mumbai

Blore
Sample size 50
Avg time 45
Std Dev 10.5

Mumbai
Sample size 60
Avg time 34
Std Dev 5.6
'''

# %%
# df1 = 20 to 59
# df2 = 102 to 169

# %%
df = pd.read_excel('CDAC_DataBook.xlsx',sheet_name='faithful')

# %%
df1 = df.iloc[20:60]
df2 = df.iloc[120:170]

# %%
df1.shape
# Out:
# (40, 2)

# %%
erupt1 = df1.eruptions
erupt2 = df2.eruptions

# %%
np.mean(erupt1)
# Out:
# np.float64(3.44745)

# %%
np.mean(erupt2)
# Out:
# np.float64(3.4876399999999994)

# %%
#mean of erupt2 is a least 0.12 more than the mean of erupt1
#
#means
#Ho: mean(erupt2) - mean(erupt1) >= 0.12
#Ha : mean(erupt2) - mean(erupt1) < 0.12

# %%
ssw.ztest(erupt2,erupt1,value = 0.12, alternative ='smaller')
# Out:
# (np.float64(-0.3196536558502502), np.float64(0.3746154475542464))

# %%
np.mean(erupt2)-np.mean(erupt1)
# Out:
# np.float64(0.040189999999999504)

# %%
.12 - (np.mean(erupt2)-np.mean(erupt1))
# can we ignot this difference
#because the p((0.3746154475542464)) value is greter the .05
# there can be aprox 40% chance for .04
# Out:
# np.float64(0.07981000000000049)

# %%
Nr = np.mean(erupt2) - np.mean(erupt1) - 0.12

# %%
Dr = (((np.std(erupt1,ddof=1))**2/len(erupt1))+((np.std(erupt2,ddof=1))**2/len(erupt2)))**0.5

# %%
Nr/Dr  # this gives test statics
# Out:
# np.float64(-0.31844451421709036)

# %%
df = pd.read_csv('6-Churn_ModellingDataSet.csv')

# %%
df.head()
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
# 3          4    15701354      Boni          699    France  Female   39
# 4          5    15737888  Mitchell          850     Spain  Female   43
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# 1       1   83807.86              1          0               1
# 2       8  159660.80              3          1               0
# 3       1       0.00              2          0               0
# 4       2  125510.82              1          1               1
#
#    EstimatedSalary  Exited
# 0        101348.88       1
# 1        112542.58       0
# 2        113931.57       1
# 3         93826.63       0
# ...
